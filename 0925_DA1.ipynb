# %% [markdown]
# #### IMPORTING LIBRARIES

# %%
import os
import pandas as pd
import numpy as np
import janitor

# %% [markdown]
# #### READING PERSONALITY DATASET

# %%
os.chdir(r"C:\Users\rosha\OneDrive\Desktop\Data Analysis\Input Files")
ppl_pers = pd.read_csv(r"people personality.csv")
ppl_pers
# Out:
#          Age  Gender  Education  Introversion Score  Sensing Score  \
# 0       19.0    Male          0             9.47080       7.141434
# 1       27.0  Female          0             5.85392       6.160195
# 2       21.0  Female          0             7.08615       3.388433
# 3       28.0    Male          0             2.01892       4.823624
# 4       36.0  Female          1             9.91703       4.755080
# ...      ...     ...        ...                 ...            ...
# 128056  27.0    Male          0             5.11456       7.764336
# 128057  19.0    Male          0             3.00078       2.525392
# 128058  26.0  Female          1             8.16219       3.433857
# 128059  24.0    Male          0             9.37782       5.077443
# 128060  27.0    Male          0             7.78827       4.770737
#
#         Thinking Score  Judging Score    Interest Personality
# 0              6.03696       4.360278     Unknown        ENFP
# ...

# %% [markdown]
# #### EDA (EXPLORATORY DATA ANALYSIS)

# %%
ppl_pers.drop_duplicates()
# Out:
#          Age  Gender  Education  Introversion Score  Sensing Score  \
# 0       19.0    Male          0             9.47080       7.141434
# 1       27.0  Female          0             5.85392       6.160195
# 2       21.0  Female          0             7.08615       3.388433
# 3       28.0    Male          0             2.01892       4.823624
# 4       36.0  Female          1             9.91703       4.755080
# ...      ...     ...        ...                 ...            ...
# 128056  27.0    Male          0             5.11456       7.764336
# 128057  19.0    Male          0             3.00078       2.525392
# 128058  26.0  Female          1             8.16219       3.433857
# 128059  24.0    Male          0             9.37782       5.077443
# 128060  27.0    Male          0             7.78827       4.770737
#
#         Thinking Score  Judging Score    Interest Personality
# 0              6.03696       4.360278     Unknown        ENFP
# ...

# %%
maximum_age = ppl_pers['Age'].max()
minimum_age = ppl_pers['Age'].min()
print("The maximum age is: ", maximum_age)
print("The minimum age is: ", minimum_age)
# Out:
# The maximum age is:  57.0
# The minimum age is:  18.0

# %%
ppl_pers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128061 entries, 0 to 128060
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Age                 128061 non-null  float64
#  1   Gender              128061 non-null  object
#  2   Education           128061 non-null  int64
#  3   Introversion Score  128061 non-null  float64
#  4   Sensing Score       128061 non-null  float64
#  5   Thinking Score      128061 non-null  float64
#  6   Judging Score       128061 non-null  float64
#  7   Interest            128061 non-null  object
#  8   Personality         128061 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 8.8+ MB

# %%
ppl_pers1 = ppl_pers.copy()

# %%
# ppl_pers1.to_clipboard(excel=True, index=False)

# %% [markdown]
# #### READING SPOTIFY DATASET

# %%
spotify_df = pd.read_csv(r"Spotify Most Streamed Songs.csv",dtype={'artist_count':'str','track_name':"str",'artist(s)_name':'str','key':'str'})
spotify_df
# Out:
#                               track_name      artist(s)_name artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook            2
# 1                                   LALA         Myke Towers            1
# 2                                vampire      Olivia Rodrigo            1
# 3                           Cruel Summer        Taylor Swift            1
# 4                         WHERE SHE GOES           Bad Bunny            1
# ..                                   ...                 ...          ...
# 948                         My Mind & Me        Selena Gomez            1
# 949            Bigger Than The Whole Sky        Taylor Swift            1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra            2
# 951                        En La De Ella  Feid, Sech, Jhayco            3
# 952                                Alone           Burna Boy            1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %% [markdown]
# #### EDA (EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ##### CHECKING FOR DUPLICATES/REDUNDANCIES IN DATASET

# %%
print(spotify_df.shape)
print(spotify_df.drop_duplicates().shape)
# Out:
# (953, 25)
# (953, 25)

# %%
spotify_df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%',
#        'cover_url'],
#       dtype='object')

# %%
df2 = spotify_df.groupby('released_year')['artist_count'].sum()

# %%
df2
# Out:
# released_year
# 1930                                                    3
# 1942                                                    3
# 1946                                                    1
# 1950                                                    2
# 1952                                                    1
# 1957                                                   11
# 1958                                                  131
# 1959                                                   11
# 1963                                                  111
# 1968                                                    1
# 1970                                                   11
# 1971                                                    4
# 1973                                                    1
# 1975                                                   11
# 1979                                                    1
# 1982                                                   11
# ...

# %%
spotify_df['Date'] = spotify_df['released_year'].astype(str)+ '-'+ \
spotify_df['released_month'].astype(str)+ '-'+ \
spotify_df['released_day'].astype(str)
spotify_df['Date']
# Out:
# 0       2023-7-14
# 1       2023-3-23
# 2       2023-6-30
# 3       2019-8-23
# 4       2023-5-18
#           ...
# 948     2022-11-3
# 949    2022-10-21
# 950     2022-11-3
# 951    2022-10-20
# 952     2022-11-4
# Name: Date, Length: 953, dtype: object

# %%
spotify_df['Date'] = pd.to_datetime(spotify_df['Date'],format='%Y-%m-%d')
spotify_df['Date']
# Out:
# 0     2023-07-14
# 1     2023-03-23
# 2     2023-06-30
# 3     2019-08-23
# 4     2023-05-18
#          ...
# 948   2022-11-03
# 949   2022-10-21
# 950   2022-11-03
# 951   2022-10-20
# 952   2022-11-04
# Name: Date, Length: 953, dtype: datetime64[ns]

# %%
spotify_df
# Out:
#                               track_name      artist(s)_name artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook            2
# 1                                   LALA         Myke Towers            1
# 2                                vampire      Olivia Rodrigo            1
# 3                           Cruel Summer        Taylor Swift            1
# 4                         WHERE SHE GOES           Bad Bunny            1
# ..                                   ...                 ...          ...
# 948                         My Mind & Me        Selena Gomez            1
# 949            Bigger Than The Whole Sky        Taylor Swift            1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra            2
# 951                        En La De Ella  Feid, Sech, Jhayco            3
# 952                                Alone           Burna Boy            1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
spotify_df['YRMO'] = spotify_df['Date'].dt.strftime('%Y%m')
spotify_df
# Out:
#                               track_name      artist(s)_name artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook            2
# 1                                   LALA         Myke Towers            1
# 2                                vampire      Olivia Rodrigo            1
# 3                           Cruel Summer        Taylor Swift            1
# 4                         WHERE SHE GOES           Bad Bunny            1
# ..                                   ...                 ...          ...
# 948                         My Mind & Me        Selena Gomez            1
# 949            Bigger Than The Whole Sky        Taylor Swift            1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra            2
# 951                        En La De Ella  Feid, Sech, Jhayco            3
# 952                                Alone           Burna Boy            1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %% [markdown]
# #### REMOVING ROWS HAVING NULLS IN KEY COLUMN

# %%
spotify_df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# cover_url                0
# Date                     0
# YRMO                     0
# dtype: int64

# %%
spotify_df1 = spotify_df[~spotify_df['key'].isna()]

# %%
spotify_df[spotify_df['key'].isna()].shape
# Out:
# (95, 27)

# %%
spotify_df1.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        41
# bpm                      0
# key                      0
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# cover_url                0
# Date                     0
# YRMO                     0
# dtype: int64

# %%
print(spotify_df1['artist(s)_name'].nunique())
print(spotify_df1['artist(s)_name'].nunique())
# Out:
# 597
# 597

# %% [markdown]
# #### REMOVING THE ROWS NOT HAVING COVER URL (NOT INCLUDING THEM IN OUR ANALYSIS)

# %%
print(spotify_df.shape)
print(spotify_df1.shape)
# Out:
# (953, 27)
# (858, 27)

# %%
print(spotify_df[spotify_df['key'].isna()].shape)
print(spotify_df1.shape)
# Out:
# (95, 27)
# (858, 27)

# %%
print(858+95)
print(spotify_df.shape)
# Out:
# 953
# (953, 27)

# %%
spotify_df1[spotify_df1['cover_url']=='Not Found']
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 9                                      La Bebe - Remix
# 10                                           un x100to
# 20                                           LADY GAGA
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# ..                                                 ...
# 920                                         BABY OTAKU
# 930                                Casei Com a Putaria
# 942                                       Con La Brisa
# 950                               A Veces (feat. Feid)
# 951                                      En La De Ella
#
#                                         artist(s)_name artist_count  \
# 0                                     Latto, Jung Kook            2
# 9                                Peso Pluma, Yng Lvcas            2
# 10                           Bad Bunny, Grupo Frontera            2
# ...

# %%
spotify_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 858 entries, 0 to 952
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            858 non-null    object
#  1   artist(s)_name        858 non-null    object
#  2   artist_count          858 non-null    object
#  3   released_year         858 non-null    int64
#  4   released_month        858 non-null    int64
#  5   released_day          858 non-null    int64
#  6   in_spotify_playlists  858 non-null    int64
#  7   in_spotify_charts     858 non-null    int64
#  8   streams               858 non-null    object
#  9   in_apple_playlists    858 non-null    int64
#  10  in_apple_charts       858 non-null    int64
#  11  in_deezer_playlists   858 non-null    object
#  12  in_deezer_charts      858 non-null    int64
#  13  in_shazam_charts      817 non-null    object
#  14  bpm                   858 non-null    int64
# ...

# %%
spotify_df_refined = spotify_df1[spotify_df1['cover_url']!='Not Found']
spotify_df_refined
# Out:
#                     track_name     artist(s)_name artist_count  released_year  \
# 1                         LALA        Myke Towers            1           2023
# 2                      vampire     Olivia Rodrigo            1           2023
# 3                 Cruel Summer       Taylor Swift            1           2019
# 4               WHERE SHE GOES          Bad Bunny            1           2023
# 5                     Sprinter  Dave, Central Cee            2           2023
# ..                         ...                ...          ...            ...
# 946                 Broke Boys   Drake, 21 Savage            2           2022
# 947              The Great War       Taylor Swift            1           2022
# 948               My Mind & Me       Selena Gomez            1           2022
# 949  Bigger Than The Whole Sky       Taylor Swift            1           2022
# 952                      Alone          Burna Boy            1           2022
#
# ...

# %%
print(spotify_df1.shape)
print(spotify_df1[spotify_df1['cover_url']=='Not Found'].shape)
print(spotify_df_refined.shape)
# Out:
# (858, 27)
# (208, 27)
# (650, 27)

# %%
print(650+208)
# Out:
# 858

# %%
spotify_df_refined.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%',
#        'cover_url', 'Date', 'YRMO'],
#       dtype='object')

# %%
spotify_df_refined['key'].isnull().sum()
# Out:
# np.int64(0)

# %%
spotify_df_refined[spotify_df_refined['key'].isna()]['artist_count']
# Out:
# Series([], Name: artist_count, dtype: object)

# %%
spotify_df_piv = spotify_df_refined.pivot_table(index=['YRMO','artist(s)_name','track_name','cover_url','key'], values='artist_count', aggfunc=np.sum).reset_index()
spotify_df_piv
# Out:
# C:\Users\rosha\AppData\Local\Temp\ipykernel_22844\1009872290.py:1: FutureWarning: The provided callable <function sum at 0x000001DF4D658FE0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   spotify_df_piv = spotify_df_refined.pivot_table(index=['YRMO','artist(s)_name','track_name','cover_url','key'], values='artist_count', aggfunc=np.sum).reset_index()
#        YRMO                                     artist(s)_name  \
# 0    194201  Bing Crosby, John Scott Trotter & His Orchestr...
# 1    194611                                      Nat King Cole
# 2    195001                  Frank Sinatra, B. Swanson Quartet
# 3    195701                                        Bobby Helms
# 4    195701                                      Frank Sinatra
# ..      ...                                                ...
# ...

# %%
spotify_df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# cover_url                0
# Date                     0
# YRMO                     0
# dtype: int64

# %%
spotify_df1['key'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 858 entries, 0 to 952
# Series name: key
# Non-Null Count  Dtype
# --------------  -----
# 858 non-null    object
# dtypes: object(1)
# memory usage: 13.4+ KB

# %%
spotify_df_refined.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        37
# bpm                      0
# key                      0
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# cover_url                0
# Date                     0
# YRMO                     0
# dtype: int64

# %%
spotify_df_piv.isnull().sum()
# Out:
# YRMO              0
# artist(s)_name    0
# track_name        0
# cover_url         0
# key               0
# artist_count      0
# dtype: int64

# %% [markdown]
# #### EXPORTING THE REQUIRED OUTPUT

# %%
os.chdir(r"C:\Users\rosha\OneDrive\Desktop\Data Analysis\Output Files")
spotify_df_piv.to_csv("SpotifyArtistCount_YRMO_ArtistName_TrackName_CoverUrl_KeyOutput.csv", index=False)
